# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from analysis_shared_functions import (
    loop_accuracy_calculations,
    load_expected_matches_real_data
)
from visualization import heatmap_plot_accuracy_metrics_pseudobulk

# %%
DATA_PATH = "../../data/output_data/"
FIGURES_PATH = "../../data/figures/"

# %%
tools = ["BAMixChecker", "CrosscheckFingerprints", "HYSYS", "NGSCheckmate", "Vireo"]
ncells_list = [5000, 10000, 50000, 100000, 500000]
read_depths = [1, 10, 20, 30, 40]
datasets = ["low_grade_glioma"]

# %%
load_expected_matches_real_data(DATA_PATH, dataset="wilms_tumor")
# Out:
#    single-nucleus sample id bulk sample id
# 0                GSM6025604   SAMN25703569
# 1                GSM6025605   SAMN25703570
# 2                GSM6025606   SAMN25703537
# 3                GSM6025607   SAMN25703538
# 4                GSM6025608   SAMN25703539
# 5                GSM6025609   SAMN25703540
# 6                GSM6025610   SAMN25703541
# 7                GSM6025611   SAMN25703542
# 8                GSM6025612   SAMN25703543
# 9                GSM6025613   SAMN25703544
# 10               GSM6025614   SAMN25703545
# 11               GSM6025615   SAMN25703571
# 12               GSM6025616   SAMN25703546
# 13               GSM6025617   SAMN25703547
# 14               GSM6025618   SAMN25703548
# 15               GSM6025619   SAMN25703572
# 16               GSM6025620   SAMN25703549
# 17               GSM6025621   SAMN25703550
# 18               GSM6025622   SAMN25703551
# 19               GSM6025623   SAMN25703553
# 20               GSM6025624   SAMN25703553
# 21               GSM6025625   SAMN25703554
# 22               GSM6025626   SAMN25703555
# 23               GSM6025627   SAMN25703573
# 24               GSM6025628   SAMN25703556
# 25               GSM6025629   SAMN25703557
# 26               GSM6025630   SAMN25703558
# 27               GSM6025631   SAMN25703559
# 28               GSM6025632   SAMN25703560
# 29               GSM6025633   SAMN25703561
# 30               GSM6025634   SAMN25703562
# 31               GSM6025635   SAMN25703563
# 32               GSM6025636   SAMN25703564
# 33               GSM6025637   SAMN25703574
# 34               GSM6025638   SAMN25703565
# 35               GSM6025639   SAMN25703566
# 36               GSM6025640   SAMN25703567
# 37               GSM6025641   SAMN25703578
# 38               GSM6025642   SAMN25703568
# 39               GSM6025643            NaN

# %%
# df = loop_accuracy_calculations(
#     DATA_PATH=DATA_PATH,
#     tools=tools,
#     datasets=datasets,
#     ncells_list=ncells_list,
#     read_depths=read_depths
#     )

# %%
# heatmap_plot_accuracy_metrics_pseudobulk(
#     df, 
#     dataset="low_grade_glioma",
#     metric="recall",
#     save_fig=True,
#     FIGURES_PATH=FIGURES_PATH
#     )
