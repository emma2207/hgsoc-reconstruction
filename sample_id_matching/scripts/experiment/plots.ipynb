# %%
from visualization import loop_heatmap_plots_pseudobulks, loop_heatmap_plots_real_data, bulk_vs_singlecell_matrix_viz

# %%
tools = ["BAMixChecker", "CrosscheckFingerprints", "HYSYS", "NGSCheckmate", "Vireo"]
# ncells_list = [500000]
read_depths = [10, 20, 30, 40]
datasets = ["hgsoc-new"]

# %%
DATA_PATH = "../../data/output_data/"
FIGURES_PATH = "../../data/figures/"

# %%
# loop_heatmap_plots_pseudobulks(
#     DATA_PATH=DATA_PATH, 
#     FIGURES_PATH=FIGURES_PATH,
#     tools=tools, 
#     datasets=datasets, 
#     ncells_list=ncells_list, 
#     read_depths=read_depths,
# )

# %%
loop_heatmap_plots_real_data(
    DATA_PATH=DATA_PATH,
    FIGURES_PATH=FIGURES_PATH,
    tools=tools,
    datasets=datasets,
    read_depths=read_depths,
)
# Out:
# Processing tool BAMixChecker, dataset hgsoc-new, read depth 1...
# (68, 68)
# Processing tool CrosscheckFingerprints, dataset hgsoc-new, read depth 1...
# (67, 67)
# Processing tool HYSYS, dataset hgsoc-new, read depth 1...
# (67, 67)
# Processing tool NGSCheckmate, dataset hgsoc-new, read depth 1...
# (67, 67)
# Processing tool Vireo, dataset hgsoc-new, read depth 1...
# (32, 32)
