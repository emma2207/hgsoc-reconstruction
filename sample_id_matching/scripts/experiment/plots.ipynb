# %%
from visualization import loop_heatmap_plots_pseudobulks, loop_heatmap_plots_real_data, bulk_vs_singlecell_matrix_viz

# %%
tools = ["BAMixChecker", "CrosscheckFingerprints", "HYSYS", "NGSCheckmate", "Vireo"]
ncells_list = [500000]
read_depths = [1]
datasets = ["wilms_tumor"]

# %%
DATA_PATH = "../../data/output_data/"
FIGURES_PATH = "../../data/figures/"

# %%
# loop_heatmap_plots_pseudobulks(
#     DATA_PATH=DATA_PATH, 
#     FIGURES_PATH=FIGURES_PATH,
#     tools=tools, 
#     datasets=datasets, 
#     ncells_list=ncells_list, 
#     read_depths=read_depths,
# )

# %%
loop_heatmap_plots_real_data(
    DATA_PATH=DATA_PATH,
    FIGURES_PATH=FIGURES_PATH,
    tools=tools,
    datasets=datasets,
    read_depths=read_depths,
)
# Out:
# Processing tool BAMixChecker, dataset wilms_tumor, read depth 1...
# Found 1 matches for SJWLM051023_D1: ['SJWLM051023_D1_bulk']
# Found 1 matches for SJWLM051023_D2: ['SJWLM051023_D2_bulk']
# Found 1 matches for SJWLM071560_D1: ['SJWLM071560_D1_bulk']
# Found 1 matches for SJWLM049191_D2: ['SJWLM049191_D2_bulk']
# Found 1 matches for SJWLM059679_D1: ['SJWLM059679_D1_bulk']
# Found 1 matches for SJWLM071550_D1: ['SJWLM071550_D1_bulk']
# Found 1 matches for SJWLM030545_D1: ['SJWLM030545_D1_bulk']
# Found 1 matches for SJWLM030545_D1: ['SJWLM030545_D1_bulk']
# Found 1 matches for SJWLM059683_D1: ['SJWLM059683_D1_bulk']
# Found 1 matches for SJWLM030043_D1: ['SJWLM030043_D1_bulk']
# Found 1 matches for SJWLM030548_D2: ['SJWLM030548_D2_bulk']
# Found 1 matches for SJWLM071563_D1: ['SJWLM071563_D1_bulk']
# Found 1 matches for SJWLM071552_D1: ['SJWLM071552_D1_bulk']
# Found 1 matches for SJWLM071553_D1: ['SJWLM071553_D1_bulk']
# Found 1 matches for SJWLM071554_D1: ['SJWLM071554_D1_bulk']
# Found 1 matches for SJWLM056073_D1: ['SJWLM056073_D1_bulk']
# Found 1 matches for SJWLM059659_D1: ['SJWLM059659_D1_bulk']
# Found 1 matches for SJWLM059660_D1: ['SJWLM059660_D1_bulk']
# Found 1 matches for SJWLM071556_D1: ['SJWLM071556_D1_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM071562_D1: ['SJWLM071562_D1_bulk']
# Found 1 matches for SJWLM071564_D1: ['SJWLM071564_D1_bulk']
# Found 1 matches for SJWLM018918_D1: ['SJWLM018918_D1_bulk']
# Found 1 matches for SJWLM071559_D1: ['SJWLM071559_D1_bulk']
# Found 1 matches for SJWLM059672_D1: ['SJWLM059672_D1_bulk']
# Found 1 matches for SJWLM030739_D2: ['SJWLM030739_D2_bulk']
# Found 1 matches for SJWLM059661_D1: ['SJWLM059661_D1_bulk']
# Found 1 matches for SJWLM056407_D1: ['SJWLM056407_D1_bulk']
# Found 1 matches for SJWLM058497_D1: ['SJWLM058497_D1_bulk']
# Found 1 matches for SJWLM056485_D1: ['SJWLM056485_D1_bulk']
# Found 1 matches for SJWLM059665_D1: ['SJWLM059665_D1_bulk']
# Found 1 matches for SJWLM071558_D1: ['SJWLM071558_D1_bulk']
# Found 1 matches for SJWLM030897_D2: ['SJWLM030897_D2_bulk']
# Found 1 matches for SJWLM043456_D1: ['SJWLM043456_D1_bulk']
# Found 1 matches for SJWLM071551_D1: ['SJWLM071551_D1_bulk']
# Found 1 matches for SJWLM056127_D1: ['SJWLM056127_D1_bulk']
# Found 1 matches for SJWLM071547_D1: ['SJWLM071547_D1_bulk']
# Found 1 matches for SJWLM071557_D1: ['SJWLM071557_D1_bulk']
# Found 1 matches for GSM6025604: ['GSM6025604_single-nucleus']
# Found 1 matches for GSM6025605: ['GSM6025605_single-nucleus']
# Found 1 matches for GSM6025606: ['GSM6025606_single-nucleus']
# Found 1 matches for GSM6025607: ['GSM6025607_single-nucleus']
# Found 1 matches for GSM6025608: ['GSM6025608_single-nucleus']
# Found 1 matches for GSM6025609: ['GSM6025609_single-nucleus']
# Found 1 matches for GSM6025610: ['GSM6025610_single-nucleus']
# Found 1 matches for GSM6025611: ['GSM6025611_single-nucleus']
# Found 1 matches for GSM6025612: ['GSM6025612_single-nucleus']
# Found 1 matches for GSM6025613: ['GSM6025613_single-nucleus']
# Found 1 matches for GSM6025614: ['GSM6025614_single-nucleus']
# Found 1 matches for GSM6025615: ['GSM6025615_single-nucleus']
# Found 1 matches for GSM6025616: ['GSM6025616_single-nucleus']
# Found 1 matches for GSM6025617: ['GSM6025617_single-nucleus']
# Found 1 matches for GSM6025618: ['GSM6025618_single-nucleus']
# Found 1 matches for GSM6025619: ['GSM6025619_single-nucleus']
# Found 1 matches for GSM6025620: ['GSM6025620_single-nucleus']
# Found 1 matches for GSM6025621: ['GSM6025621_single-nucleus']
# Found 1 matches for GSM6025622: ['GSM6025622_single-nucleus']
# Found 1 matches for GSM6025623: ['GSM6025623_single-nucleus']
# Found 1 matches for GSM6025624: ['GSM6025624_single-nucleus']
# Found 1 matches for GSM6025625: ['GSM6025625_single-nucleus']
# Found 1 matches for GSM6025626: ['GSM6025626_single-nucleus']
# Found 1 matches for GSM6025627: ['GSM6025627_single-nucleus']
# Found 1 matches for GSM6025628: ['GSM6025628_single-nucleus']
# Found 1 matches for GSM6025629: ['GSM6025629_single-nucleus']
# Found 1 matches for GSM6025630: ['GSM6025630_single-nucleus']
# Found 1 matches for GSM6025631: ['GSM6025631_single-nucleus']
# Found 1 matches for GSM6025632: ['GSM6025632_single-nucleus']
# Found 1 matches for GSM6025633: ['GSM6025633_single-nucleus']
# Found 1 matches for GSM6025634: ['GSM6025634_single-nucleus']
# Found 1 matches for GSM6025635: ['GSM6025635_single-nucleus']
# Found 1 matches for GSM6025636: ['GSM6025636_single-nucleus']
# Found 1 matches for GSM6025637: ['GSM6025637_single-nucleus']
# Found 1 matches for GSM6025638: ['GSM6025638_single-nucleus']
# Found 1 matches for GSM6025639: ['GSM6025639_single-nucleus']
# Found 1 matches for GSM6025640: ['GSM6025640_single-nucleus']
# Found 1 matches for GSM6025641: ['GSM6025641_single-nucleus']
# Found 1 matches for GSM6025642: ['GSM6025642_single-nucleus']
# Found 1 matches for GSM6025643: ['GSM6025643_single-nucleus']
# Processing tool CrosscheckFingerprints, dataset wilms_tumor, read depth 1...
# Found 1 matches for SJWLM051023_D1: ['SJWLM051023_D1_bulk']
# Found 1 matches for SJWLM051023_D2: ['SJWLM051023_D2_bulk']
# Found 1 matches for SJWLM071560_D1: ['SJWLM071560_D1_bulk']
# Found 1 matches for SJWLM049191_D2: ['SJWLM049191_D2_bulk']
# Found 1 matches for SJWLM059679_D1: ['SJWLM059679_D1_bulk']
# Found 1 matches for SJWLM071550_D1: ['SJWLM071550_D1_bulk']
# Found 1 matches for SJWLM030545_D1: ['SJWLM030545_D1_bulk']
# Found 1 matches for SJWLM030545_D1: ['SJWLM030545_D1_bulk']
# Found 1 matches for SJWLM059683_D1: ['SJWLM059683_D1_bulk']
# Found 1 matches for SJWLM030043_D1: ['SJWLM030043_D1_bulk']
# Found 1 matches for SJWLM030548_D2: ['SJWLM030548_D2_bulk']
# Found 1 matches for SJWLM071563_D1: ['SJWLM071563_D1_bulk']
# Found 1 matches for SJWLM071552_D1: ['SJWLM071552_D1_bulk']
# Found 1 matches for SJWLM071553_D1: ['SJWLM071553_D1_bulk']
# Found 1 matches for SJWLM071554_D1: ['SJWLM071554_D1_bulk']
# Found 1 matches for SJWLM056073_D1: ['SJWLM056073_D1_bulk']
# Found 1 matches for SJWLM059659_D1: ['SJWLM059659_D1_bulk']
# Found 1 matches for SJWLM059660_D1: ['SJWLM059660_D1_bulk']
# Found 1 matches for SJWLM071556_D1: ['SJWLM071556_D1_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM071562_D1: ['SJWLM071562_D1_bulk']
# Found 1 matches for SJWLM071564_D1: ['SJWLM071564_D1_bulk']
# Found 1 matches for SJWLM018918_D1: ['SJWLM018918_D1_bulk']
# Found 1 matches for SJWLM071559_D1: ['SJWLM071559_D1_bulk']
# Found 1 matches for SJWLM059672_D1: ['SJWLM059672_D1_bulk']
# Found 1 matches for SJWLM030739_D2: ['SJWLM030739_D2_bulk']
# Found 1 matches for SJWLM059661_D1: ['SJWLM059661_D1_bulk']
# Found 1 matches for SJWLM056407_D1: ['SJWLM056407_D1_bulk']
# Found 1 matches for SJWLM058497_D1: ['SJWLM058497_D1_bulk']
# Found 1 matches for SJWLM056485_D1: ['SJWLM056485_D1_bulk']
# Found 1 matches for SJWLM059665_D1: ['SJWLM059665_D1_bulk']
# Found 1 matches for SJWLM071558_D1: ['SJWLM071558_D1_bulk']
# Found 1 matches for SJWLM030897_D2: ['SJWLM030897_D2_bulk']
# Found 1 matches for SJWLM043456_D1: ['SJWLM043456_D1_bulk']
# Found 1 matches for SJWLM071551_D1: ['SJWLM071551_D1_bulk']
# Found 1 matches for SJWLM056127_D1: ['SJWLM056127_D1_bulk']
# Found 1 matches for SJWLM071547_D1: ['SJWLM071547_D1_bulk']
# Found 1 matches for SJWLM071557_D1: ['SJWLM071557_D1_bulk']
# Found 1 matches for GSM6025604: ['GSM6025604_single-nucleus']
# Found 1 matches for GSM6025605: ['GSM6025605_single-nucleus']
# Found 1 matches for GSM6025606: ['GSM6025606_single-nucleus']
# Found 1 matches for GSM6025607: ['GSM6025607_single-nucleus']
# Found 1 matches for GSM6025608: ['GSM6025608_single-nucleus']
# Found 1 matches for GSM6025609: ['GSM6025609_single-nucleus']
# Found 1 matches for GSM6025610: ['GSM6025610_single-nucleus']
# Found 1 matches for GSM6025611: ['GSM6025611_single-nucleus']
# Found 1 matches for GSM6025612: ['GSM6025612_single-nucleus']
# Found 1 matches for GSM6025613: ['GSM6025613_single-nucleus']
# Found 1 matches for GSM6025614: ['GSM6025614_single-nucleus']
# Found 1 matches for GSM6025615: ['GSM6025615_single-nucleus']
# Found 1 matches for GSM6025616: ['GSM6025616_single-nucleus']
# Found 1 matches for GSM6025617: ['GSM6025617_single-nucleus']
# Found 1 matches for GSM6025618: ['GSM6025618_single-nucleus']
# Found 1 matches for GSM6025619: ['GSM6025619_single-nucleus']
# Found 1 matches for GSM6025620: ['GSM6025620_single-nucleus']
# Found 1 matches for GSM6025621: ['GSM6025621_single-nucleus']
# Found 1 matches for GSM6025622: ['GSM6025622_single-nucleus']
# Found 1 matches for GSM6025623: ['GSM6025623_single-nucleus']
# Found 1 matches for GSM6025624: ['GSM6025624_single-nucleus']
# Found 1 matches for GSM6025625: ['GSM6025625_single-nucleus']
# Found 1 matches for GSM6025626: ['GSM6025626_single-nucleus']
# Found 1 matches for GSM6025627: ['GSM6025627_single-nucleus']
# Found 1 matches for GSM6025628: ['GSM6025628_single-nucleus']
# Found 1 matches for GSM6025629: ['GSM6025629_single-nucleus']
# Found 1 matches for GSM6025630: ['GSM6025630_single-nucleus']
# Found 1 matches for GSM6025631: ['GSM6025631_single-nucleus']
# Found 1 matches for GSM6025632: ['GSM6025632_single-nucleus']
# Found 1 matches for GSM6025633: ['GSM6025633_single-nucleus']
# Found 1 matches for GSM6025634: ['GSM6025634_single-nucleus']
# Found 1 matches for GSM6025635: ['GSM6025635_single-nucleus']
# Found 1 matches for GSM6025636: ['GSM6025636_single-nucleus']
# Found 1 matches for GSM6025637: ['GSM6025637_single-nucleus']
# Found 1 matches for GSM6025638: ['GSM6025638_single-nucleus']
# Found 1 matches for GSM6025639: ['GSM6025639_single-nucleus']
# Found 1 matches for GSM6025640: ['GSM6025640_single-nucleus']
# Found 1 matches for GSM6025641: ['GSM6025641_single-nucleus']
# Found 1 matches for GSM6025642: ['GSM6025642_single-nucleus']
# Found 1 matches for GSM6025643: ['GSM6025643_single-nucleus']
# Processing tool HYSYS, dataset wilms_tumor, read depth 1...
# Found 1 matches for SJWLM051023_D1: ['SJWLM051023_D1_bulk']
# Found 1 matches for SJWLM051023_D2: ['SJWLM051023_D2_bulk']
# Found 1 matches for SJWLM071560_D1: ['SJWLM071560_D1_bulk']
# Found 1 matches for SJWLM049191_D2: ['SJWLM049191_D2_bulk']
# Found 1 matches for SJWLM059679_D1: ['SJWLM059679_D1_bulk']
# Found 1 matches for SJWLM071550_D1: ['SJWLM071550_D1_bulk']
# Found 1 matches for SJWLM030545_D1: ['SJWLM030545_D1_bulk']
# Found 1 matches for SJWLM030545_D1: ['SJWLM030545_D1_bulk']
# Found 1 matches for SJWLM059683_D1: ['SJWLM059683_D1_bulk']
# Found 1 matches for SJWLM030043_D1: ['SJWLM030043_D1_bulk']
# Found 1 matches for SJWLM030548_D2: ['SJWLM030548_D2_bulk']
# Found 1 matches for SJWLM071563_D1: ['SJWLM071563_D1_bulk']
# Found 1 matches for SJWLM071552_D1: ['SJWLM071552_D1_bulk']
# Found 1 matches for SJWLM071553_D1: ['SJWLM071553_D1_bulk']
# Found 1 matches for SJWLM071554_D1: ['SJWLM071554_D1_bulk']
# Found 1 matches for SJWLM056073_D1: ['SJWLM056073_D1_bulk']
# Found 1 matches for SJWLM059659_D1: ['SJWLM059659_D1_bulk']
# Found 1 matches for SJWLM059660_D1: ['SJWLM059660_D1_bulk']
# Found 1 matches for SJWLM071556_D1: ['SJWLM071556_D1_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM071562_D1: ['SJWLM071562_D1_bulk']
# Found 1 matches for SJWLM071564_D1: ['SJWLM071564_D1_bulk']
# Found 1 matches for SJWLM018918_D1: ['SJWLM018918_D1_bulk']
# Found 1 matches for SJWLM071559_D1: ['SJWLM071559_D1_bulk']
# Found 1 matches for SJWLM059672_D1: ['SJWLM059672_D1_bulk']
# Found 1 matches for SJWLM030739_D2: ['SJWLM030739_D2_bulk']
# Found 1 matches for SJWLM059661_D1: ['SJWLM059661_D1_bulk']
# Found 1 matches for SJWLM056407_D1: ['SJWLM056407_D1_bulk']
# Found 1 matches for SJWLM058497_D1: ['SJWLM058497_D1_bulk']
# Found 1 matches for SJWLM056485_D1: ['SJWLM056485_D1_bulk']
# Found 1 matches for SJWLM059665_D1: ['SJWLM059665_D1_bulk']
# Found 1 matches for SJWLM071558_D1: ['SJWLM071558_D1_bulk']
# Found 1 matches for SJWLM030897_D2: ['SJWLM030897_D2_bulk']
# Found 1 matches for SJWLM043456_D1: ['SJWLM043456_D1_bulk']
# Found 1 matches for SJWLM071551_D1: ['SJWLM071551_D1_bulk']
# Found 1 matches for SJWLM056127_D1: ['SJWLM056127_D1_bulk']
# Found 1 matches for SJWLM071547_D1: ['SJWLM071547_D1_bulk']
# Found 1 matches for SJWLM071557_D1: ['SJWLM071557_D1_bulk']
# Found 1 matches for GSM6025604: ['GSM6025604_single-nucleus']
# Found 1 matches for GSM6025605: ['GSM6025605_single-nucleus']
# Found 1 matches for GSM6025606: ['GSM6025606_single-nucleus']
# Found 1 matches for GSM6025607: ['GSM6025607_single-nucleus']
# Found 1 matches for GSM6025608: ['GSM6025608_single-nucleus']
# Found 1 matches for GSM6025609: ['GSM6025609_single-nucleus']
# Found 1 matches for GSM6025610: ['GSM6025610_single-nucleus']
# Found 1 matches for GSM6025611: ['GSM6025611_single-nucleus']
# Found 1 matches for GSM6025612: ['GSM6025612_single-nucleus']
# Found 1 matches for GSM6025613: ['GSM6025613_single-nucleus']
# Found 1 matches for GSM6025614: ['GSM6025614_single-nucleus']
# Found 1 matches for GSM6025615: ['GSM6025615_single-nucleus']
# Found 1 matches for GSM6025616: ['GSM6025616_single-nucleus']
# Found 1 matches for GSM6025617: ['GSM6025617_single-nucleus']
# Found 1 matches for GSM6025618: ['GSM6025618_single-nucleus']
# Found 1 matches for GSM6025619: ['GSM6025619_single-nucleus']
# Found 1 matches for GSM6025620: ['GSM6025620_single-nucleus']
# Found 1 matches for GSM6025621: ['GSM6025621_single-nucleus']
# Found 1 matches for GSM6025622: ['GSM6025622_single-nucleus']
# Found 1 matches for GSM6025623: ['GSM6025623_single-nucleus']
# Found 1 matches for GSM6025624: ['GSM6025624_single-nucleus']
# Found 1 matches for GSM6025625: ['GSM6025625_single-nucleus']
# Found 1 matches for GSM6025626: ['GSM6025626_single-nucleus']
# Found 1 matches for GSM6025627: ['GSM6025627_single-nucleus']
# Found 1 matches for GSM6025628: ['GSM6025628_single-nucleus']
# Found 1 matches for GSM6025629: ['GSM6025629_single-nucleus']
# Found 1 matches for GSM6025630: ['GSM6025630_single-nucleus']
# Found 1 matches for GSM6025631: ['GSM6025631_single-nucleus']
# Found 1 matches for GSM6025632: ['GSM6025632_single-nucleus']
# Found 1 matches for GSM6025633: ['GSM6025633_single-nucleus']
# Found 1 matches for GSM6025634: ['GSM6025634_single-nucleus']
# Found 1 matches for GSM6025635: ['GSM6025635_single-nucleus']
# Found 1 matches for GSM6025636: ['GSM6025636_single-nucleus']
# Found 1 matches for GSM6025637: ['GSM6025637_single-nucleus']
# Found 1 matches for GSM6025638: ['GSM6025638_single-nucleus']
# Found 1 matches for GSM6025639: ['GSM6025639_single-nucleus']
# Found 1 matches for GSM6025640: ['GSM6025640_single-nucleus']
# Found 1 matches for GSM6025641: ['GSM6025641_single-nucleus']
# Found 1 matches for GSM6025642: ['GSM6025642_single-nucleus']
# Found 1 matches for GSM6025643: ['GSM6025643_single-nucleus']
# Processing tool NGSCheckmate, dataset wilms_tumor, read depth 1...
# Could not find data for NGSCheckmate, real dataset wilms_tumor, read depth 1.
# Processing tool Vireo, dataset wilms_tumor, read depth 1...
# Found 1 matches for SJWLM051023_D1: ['SJWLM051023_D1_bulk']
# Found 1 matches for SJWLM051023_D2: ['SJWLM051023_D2_bulk']
# Found 1 matches for SJWLM071560_D1: ['SJWLM071560_D1_bulk']
# Found 1 matches for SJWLM049191_D2: ['SJWLM049191_D2_bulk']
# Found 1 matches for SJWLM059679_D1: ['SJWLM059679_D1_bulk']
# Found 1 matches for SJWLM071550_D1: ['SJWLM071550_D1_bulk']
# Warning: No match found in matrix for expected sample 'SJWLM030545_D1'
# Warning: No match found in matrix for expected sample 'SJWLM030545_D1'
# Warning: No match found in matrix for expected sample 'SJWLM059683_D1'
# Found 1 matches for SJWLM030043_D1: ['SJWLM030043_D1_bulk']
# Found 1 matches for SJWLM030548_D2: ['SJWLM030548_D2_bulk']
# Found 1 matches for SJWLM071563_D1: ['SJWLM071563_D1_bulk']
# Found 1 matches for SJWLM071552_D1: ['SJWLM071552_D1_bulk']
# Found 1 matches for SJWLM071553_D1: ['SJWLM071553_D1_bulk']
# Found 1 matches for SJWLM071554_D1: ['SJWLM071554_D1_bulk']
# Found 1 matches for SJWLM056073_D1: ['SJWLM056073_D1_bulk']
# Found 1 matches for SJWLM059659_D1: ['SJWLM059659_D1_bulk']
# Found 1 matches for SJWLM059660_D1: ['SJWLM059660_D1_bulk']
# Found 1 matches for SJWLM071556_D1: ['SJWLM071556_D1_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM051026_D2: ['SJWLM051026_D2_bulk']
# Found 1 matches for SJWLM071562_D1: ['SJWLM071562_D1_bulk']
# Found 1 matches for SJWLM071564_D1: ['SJWLM071564_D1_bulk']
# Found 1 matches for SJWLM018918_D1: ['SJWLM018918_D1_bulk']
# Found 1 matches for SJWLM071559_D1: ['SJWLM071559_D1_bulk']
# Found 1 matches for SJWLM059672_D1: ['SJWLM059672_D1_bulk']
# Found 1 matches for SJWLM030739_D2: ['SJWLM030739_D2_bulk']
# Found 1 matches for SJWLM059661_D1: ['SJWLM059661_D1_bulk']
# Found 1 matches for SJWLM056407_D1: ['SJWLM056407_D1_bulk']
# Found 1 matches for SJWLM058497_D1: ['SJWLM058497_D1_bulk']
# Found 1 matches for SJWLM056485_D1: ['SJWLM056485_D1_bulk']
# Found 1 matches for SJWLM059665_D1: ['SJWLM059665_D1_bulk']
# Found 1 matches for SJWLM071558_D1: ['SJWLM071558_D1_bulk']
# Found 1 matches for SJWLM030897_D2: ['SJWLM030897_D2_bulk']
# Found 1 matches for SJWLM043456_D1: ['SJWLM043456_D1_bulk']
# Found 1 matches for SJWLM071551_D1: ['SJWLM071551_D1_bulk']
# Found 1 matches for SJWLM056127_D1: ['SJWLM056127_D1_bulk']
# Found 1 matches for SJWLM071547_D1: ['SJWLM071547_D1_bulk']
# Found 1 matches for SJWLM071557_D1: ['SJWLM071557_D1_bulk']
# Warning: No match found in matrix for expected sample 'GSM6025604'
# Warning: No match found in matrix for expected sample 'GSM6025605'
# Warning: No match found in matrix for expected sample 'GSM6025606'
# Warning: No match found in matrix for expected sample 'GSM6025607'
# Warning: No match found in matrix for expected sample 'GSM6025608'
# Warning: No match found in matrix for expected sample 'GSM6025609'
# Warning: No match found in matrix for expected sample 'GSM6025610'
# Warning: No match found in matrix for expected sample 'GSM6025611'
# Warning: No match found in matrix for expected sample 'GSM6025612'
# Warning: No match found in matrix for expected sample 'GSM6025613'
# Warning: No match found in matrix for expected sample 'GSM6025614'
# Warning: No match found in matrix for expected sample 'GSM6025615'
# Warning: No match found in matrix for expected sample 'GSM6025616'
# Warning: No match found in matrix for expected sample 'GSM6025617'
# Warning: No match found in matrix for expected sample 'GSM6025618'
# Warning: No match found in matrix for expected sample 'GSM6025619'
# Warning: No match found in matrix for expected sample 'GSM6025620'
# Warning: No match found in matrix for expected sample 'GSM6025621'
# Warning: No match found in matrix for expected sample 'GSM6025622'
# Warning: No match found in matrix for expected sample 'GSM6025623'
# Warning: No match found in matrix for expected sample 'GSM6025624'
# Warning: No match found in matrix for expected sample 'GSM6025625'
# Warning: No match found in matrix for expected sample 'GSM6025626'
# Warning: No match found in matrix for expected sample 'GSM6025627'
# Warning: No match found in matrix for expected sample 'GSM6025628'
# Warning: No match found in matrix for expected sample 'GSM6025629'
# Warning: No match found in matrix for expected sample 'GSM6025630'
# Warning: No match found in matrix for expected sample 'GSM6025631'
# Warning: No match found in matrix for expected sample 'GSM6025632'
# Warning: No match found in matrix for expected sample 'GSM6025633'
# Warning: No match found in matrix for expected sample 'GSM6025634'
# Warning: No match found in matrix for expected sample 'GSM6025635'
# Warning: No match found in matrix for expected sample 'GSM6025636'
# Warning: No match found in matrix for expected sample 'GSM6025637'
# Warning: No match found in matrix for expected sample 'GSM6025638'
# Warning: No match found in matrix for expected sample 'GSM6025639'
# Warning: No match found in matrix for expected sample 'GSM6025640'
# Warning: No match found in matrix for expected sample 'GSM6025641'
# Warning: No match found in matrix for expected sample 'GSM6025642'
# Warning: No match found in matrix for expected sample 'GSM6025643'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 loop_heatmap_plots_real_data(
#       2     DATA_PATH=DATA_PATH,
#       3     FIGURES_PATH=FIGURES_PATH,
#       4     tools=tools,
#       5     datasets=datasets,
#       6     read_depths=read_depths,
#       7 )
#
# File ~/Documents/HGSOC/hgsoc-power/sample_id_matching/scripts/experiment/visualization.py:271, in loop_heatmap_plots_real_data(DATA_PATH, FIGURES_PATH, tools, datasets, read_depths, bulk)
#     268         print(f"Warning: No match found in matrix for expected sample '{expected_sample}'")
#     270 # Reorder matrix with matched samples
# --> 271 matrix = matrix.loc[ordered_matrix_samples, ordered_matrix_samples]
#     273 # Create plots
#     274 bulk_vs_singlecell_matrix_viz(
#     275     matrix,
#     276     pseudobulk=False,
#    (...)    282     FIGURES_PATH=FIGURES_PATH
#     283 )
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
#    1389 tup = self._validate_tuple_indexer(tup)
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexing.py:1093, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1089 for i, key in zip(range(len(tup) - 1, -1, -1), reversed(tup), strict=True):
#    1090     if is_label_like(key) or is_list_like(key):
#    1091         # We don't need to check for tuples here because those are
#    1092         #  caught by the _is_nested_tuple_indexer check above.
# -> 1093         section = self._getitem_axis(key, axis=i)
#    1095         # We should never have a scalar section here, because
#    1096         #  _getitem_lowerdim is only called after a check for
#    1097         #  is_scalar_access, which that would be.
#    1098         if section.ndim == self.ndim:
#    1099             # we're in the middle of slicing through a MultiIndex
#    1100             # revise the key wrt to `section` by inserting an _NS
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/analysis/lib/python3.14/site-packages/pandas/core/indexes/base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['SJWLM051023_D1_bulk', 'SJWLM051023_D2_bulk', 'SJWLM071560_D1_bulk',\n       'SJWLM049191_D2_bulk', 'SJWLM059679_D1_bulk', 'SJWLM071550_D1_bulk',\n       'SJWLM030043_D1_bulk', 'SJWLM030548_D2_bulk', 'SJWLM071563_D1_bulk',\n       'SJWLM071552_D1_bulk', 'SJWLM071553_D1_bulk', 'SJWLM071554_D1_bulk',\n       'SJWLM056073_D1_bulk', 'SJWLM059659_D1_bulk', 'SJWLM059660_D1_bulk',\n       'SJWLM071556_D1_bulk', 'SJWLM051026_D2_bulk', 'SJWLM051026_D2_bulk',\n       'SJWLM071562_D1_bulk', 'SJWLM071564_D1_bulk', 'SJWLM018918_D1_bulk',\n       'SJWLM071559_D1_bulk', 'SJWLM059672_D1_bulk', 'SJWLM030739_D2_bulk',\n       'SJWLM059661_D1_bulk', 'SJWLM056407_D1_bulk', 'SJWLM058497_D1_bulk',\n       'SJWLM056485_D1_bulk', 'SJWLM059665_D1_bulk', 'SJWLM071558_D1_bulk',\n       'SJWLM030897_D2_bulk', 'SJWLM043456_D1_bulk', 'SJWLM071551_D1_bulk',\n       'SJWLM056127_D1_bulk', 'SJWLM071547_D1_bulk', 'SJWLM071557_D1_bulk'],\n      dtype='str')] are in the [columns]"
